# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbr

# %%
df = pd.read_csv("2019.csv")
df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
dataIndex = ['Mean','Median','Modus','Range','Q1','Q3','IQR','Standar Deviasi','Variance']
dataColumns = ['Score', 'GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices','Generosity','Perceptions of corruption']
s = [0,1,2,3,4,5,6]
df2 = pd.DataFrame(index = dataIndex,columns = dataColumns)

for i in range(len(dataColumns)):
    df2[dataColumns[i]] = [df[dataColumns[i]].mean(),df[dataColumns[i]].median(),df[dataColumns[i]].mode(),(df[dataColumns[i]].max())-(df[dataColumns[i]].min()),np.quantile(df[dataColumns[i]], .25),np.quantile(df[dataColumns[i]], .75),(np.quantile(df[dataColumns[i]], .75))-(np.quantile(df[dataColumns[i]], .25)),np.std(df[dataColumns[i]]),np.var(df[dataColumns[i]])]
df2
# Out:
#                                      Score            GDP per capita  \
# Mean                                5.4071                  0.905147
# Median                              5.3795                      0.96
# Modus            0    5.208
# dtype: float64  0    0.96
# dtype: float64
# Range                                4.916                     1.684
# Q1                                  4.5445                   0.60275
# Q3                                  6.1845                    1.2325
# IQR                                   1.64                   0.62975
# Standar Deviasi                    1.10955                  0.397111
# Variance                           1.23109                  0.157697
#
#                             Social support  \
# Mean                               1.20881
# Median                              1.2715
# Modus            0    1.465
# dtype: float64
# Range                                1.624
# Q1                                 1.05575
# ...

# %% [markdown]
# ### Z-Score

# %%
dfzscore = df.drop(["Overall rank"], axis=1)
for i in dataColumns :
    zscore = i + "z-score"
    dfzscore[zscore] = (dfzscore[i] - dfzscore[i].mean())/dfzscore[i].std(ddof=1)
dfzscore
# Out:
#             Country or region  Score  GDP per capita  Social support  \
# 0                     Finland  7.769           1.340           1.587
# 1                     Denmark  7.600           1.383           1.573
# 2                      Norway  7.554           1.488           1.582
# 3                     Iceland  7.494           1.380           1.624
# 4                 Netherlands  7.488           1.396           1.522
# ..                        ...    ...             ...             ...
# 151                    Rwanda  3.334           0.359           0.711
# 152                  Tanzania  3.231           0.476           0.885
# 153               Afghanistan  3.203           0.350           0.517
# 154  Central African Republic  3.083           0.026           0.000
# 155               South Sudan  2.853           0.306           0.575
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# ...

# %% [markdown]
# ### High Ouliers & Low Outliers

# %%
# Menentukan High Ouliers & Low Outliers
dataIndex = ['ZScore-High','ZScore-Low','IQR-High','IQR-Low']
dataColumns = ['Score', 'GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices','Generosity','Perceptions of corruption']
s = [0,1,2,3,4,5,6]
zdf = pd.DataFrame(index = dataIndex,columns = dataColumns)

for i in range(len(dataColumns)):
    zdf[dataColumns[i]] = [df[dataColumns[i]].mean() + (2*np.std(df[dataColumns[i]])),df[dataColumns[i]].mean() - (2*np.std(df[dataColumns[i]])), np.quantile(df[dataColumns[i]], .75)+1.5 * (np.quantile(df[dataColumns[i]], .75))-(np.quantile(df[dataColumns[i]], .25)), np.quantile(df[dataColumns[i]], .25)-1.5 * (np.quantile(df[dataColumns[i]], .75))-(np.quantile(df[dataColumns[i]], .25))]
zdf
# Out:
#               Score  GDP per capita  Social support  Healthy life expectancy  \
# Z-High     7.626189        1.699368        1.805276                 1.207937
# Z-Low      3.188003        0.110926        0.612352                 0.242550
# IQR-High  10.916750        2.478500        2.575500                 1.656625
# IQR-Low   -9.276750       -1.848750       -2.178750                -1.322625
#
#           Freedom to make life choices  Generosity  Perceptions of corruption
# Z-High                        0.678229    0.374743                   0.299071
# Z-Low                         0.106912   -0.005051                  -0.077866
# IQR-High                      0.960125    0.511875                   0.306125
# IQR-Low                      -0.760875   -0.372375                  -0.211875

# %% [markdown]
# ### Boxplot

# %%
# BoxPlot
x = []
for i in range(len(dataColumns)):
    x.append(df[dataColumns[i]])
fig, axis = plt.subplots(figsize=(16,8))
axis.boxplot(x, vert=True)
plt.show()

# %% [markdown]
# ### Histogram

# %%
bins = np.linspace((df[dataColumns[0]].min()-0.5),(df[dataColumns[0]].max()+0.5), 30)
plt.hist(df[dataColumns[0]], bins)
plt.title('Score')
plt.show()

# %%
bins = np.linspace((df[dataColumns[1]].min()-0.5),(df[dataColumns[1]].max()+0.5), 30)
plt.hist(df[dataColumns[1]], bins)
plt.title('GDP per kapita')
plt.show()

# %%
bins = np.linspace((df[dataColumns[2]].min()-0.5),(df[dataColumns[2]].max()+0.5), 30)
plt.hist(df[dataColumns[2]], bins)
plt.title('Social support')
plt.show()

# %%
bins = np.linspace((df[dataColumns[3]].min()-0.5),(df[dataColumns[3]].max()+0.5), 30)
plt.hist(df[dataColumns[3]], bins)
plt.title('Healthy life expectancy')
plt.show()

# %%
bins = np.linspace((df[dataColumns[4]].min()-0.5),(df[dataColumns[4]].max()+0.5), 30)
plt.hist(df[dataColumns[4]], bins)
plt.title('Freedom to make life choices')
plt.show()

# %%
bins = np.linspace((df[dataColumns[5]].min()-0.5),(df[dataColumns[5]].max()+0.5), 30)
plt.hist(df[dataColumns[5]], bins)
plt.title('Generosity')
plt.show()

# %%
bins = np.linspace((df[dataColumns[6]].min()-0.5),(df[dataColumns[6]].max()+0.5), 30)
plt.hist(df[dataColumns[6]], bins)
plt.title('Perceptions of corruption')
plt.show()

# %%
dfnew = df.drop(["Overall rank","Country or region"], axis=1)
dfnew
# Out:
#      Score  GDP per capita  Social support  Healthy life expectancy  \
# 0    7.769           1.340           1.587                    0.986
# 1    7.600           1.383           1.573                    0.996
# 2    7.554           1.488           1.582                    1.028
# 3    7.494           1.380           1.624                    1.026
# 4    7.488           1.396           1.522                    0.999
# ..     ...             ...             ...                      ...
# 151  3.334           0.359           0.711                    0.614
# 152  3.231           0.476           0.885                    0.499
# 153  3.203           0.350           0.517                    0.361
# 154  3.083           0.026           0.000                    0.105
# 155  2.853           0.306           0.575                    0.295
#
#      Freedom to make life choices  Generosity  Perceptions of corruption
# 0                           0.596       0.153                      0.393
# ...

# %% [markdown]
# ### Covariance

# %%
# Covariance
dfnew.cov()
# Out:
#                                  Score  GDP per capita  Social support  \
# Score                         1.239036        0.352052        0.258788
# GDP per capita                0.352052        0.158714        0.089981
# Social support                0.258788        0.089981        0.089515
# Healthy life expectancy       0.210189        0.080588        0.052086
# Freedom to make life choices  0.090394        0.021640        0.019178
# Generosity                    0.008040       -0.003023       -0.001372
# Perceptions of corruption     0.040579        0.011258        0.005145
#
#                               Healthy life expectancy  \
# Score                                        0.210189
# GDP per capita                               0.080588
# Social support                               0.052086
# Healthy life expectancy                      0.058624
# Freedom to make life choices                 0.013544
# Generosity                                  -0.000681
# ...

# %% [markdown]
# ### Correlation

# %%
# Pearson
sbr.heatmap(dfnew.corr(method='pearson'), cmap='hot', annot=True)

# %%
# kendall
sbr.heatmap(dfnew.corr(method='kendall'), cmap='hot', annot=True)

# %%
# Spearman
sbr.heatmap(dfnew.corr(method='spearman'), cmap='hot', annot=True)

# %% [markdown]
# ### Bar Plot

# %%
dfnew = df.sort_values('GDP per capita', ascending=False)
dfgdp = dfnew.head(10)
x = dfgdp['Country or region']
y = dfgdp['GDP per capita']

plt.bar(x, y, color='r') # red


plt.title('GDP Tertinggi')
plt.xlabel('Negara')
plt.ylabel('GDP')
plt.xticks(rotation=65)

plt.show()

# %%
dfnew = df.sort_values('Healthy life expectancy', ascending=False)
dfgdp = dfnew.head(10)
x = dfgdp['Country or region']
y = dfgdp['Healthy life expectancy']

plt.bar(x, y, color='r') # red


plt.title('Healthy life expectancy Tertinggi')
plt.xlabel('Negara')
plt.ylabel('Healthy life expectancy')
plt.xticks(rotation=65)

plt.show()

# %%
dfnew = df.sort_values('Perceptions of corruption', ascending=False)
dfgdp = dfnew.head(10)
x = dfgdp['Country or region']
y = dfgdp['Perceptions of corruption']

plt.bar(x, y, color='r') # red


plt.title('Perceptions of corruption Tertinggi')
plt.xlabel('Negara')
plt.ylabel('Perceptions of corruption')
plt.xticks(rotation=65)

plt.show()
